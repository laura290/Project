# %% [markdown]
# ## Evaluación de los protocolos de contaminación de la atmosfera en diferentes paises

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(filename='input/contaminación.png')

# %% [markdown]
# Se va a proceder a la evaluación de la efectividad de los distintos protocolos implantados a nivel mundial en diferentes paises.Para ello se analizaran  distintos datos que se encuentran reflejados en la tabla inferior.

# %%
Image(filename='input/dataframe.png')

# %% [markdown]
# En la tabla superior se puede observar los distintos paises,en diferentes decadas y el número total de muertos que han tenido cada país debido a la contaminación atmosférica.Se pueden observar datos de como afecta esta contaminación en espacios tanto abiertos como cerrados.
# Y en espacios cerrados se pueden observar diferentes tipos de contaminantes,el ozono,contaminante de tipo secundario,producido por la degradación del oxigeno en la atmosfera, y por otra parte el resto de contaminates producidos por las distintas actividades antropogénicas.

# %% [markdown]
# Se analizan los datos de los diferentes paises,representando el número total de muertos frente a cada década,pudiendose observar un descenso del número de estos en la última década en la gran mayoría,cuando comenzaron a aplicarse los protocolos de manera más exahustiva.

# %%
Image(filename='input/Paises-Decada.png')

# %% [markdown]
# No sólo se evaluaron los paises a nivel global,también se hizo de manera individual,se eligieron paises más desarrollados y menos,para hacer una comparativa,observandose un mayor número de muertos en aquellos menos desarrollados,y con menos recursos para invertir en medidas preventivas.Se puede observar algún dato representativo en la tabla de la parte inferior.

# %%
Image(filename='input/PaisesMas.png')

# %% [markdown]
# Una vez evaluado a nivel global el comportamiento de los distintos paises frente a los contaminantes atmosféricos,se puede concluir que aquellos paises con mayores recursos ecónomicos para tomar medidas preventivas,las cuales son descritas en los distintos protocolos,tienen un número menor de muertos,y que anivel general,este disminuyo en la última década.

# %% [markdown]
# ## Comportamiento de los contaminantes Outdoor vs Indoor

# %% [markdown]
# Se representan los datos globales de número de muertos causados por los mismos contaminantes tanto en espacios abiertos,como en estancias cerradas, a priori se puede observar que el número de muertos asciende en el caso de zonas cerradas,puesto que se produce una menor renovación del aire.

# %%
Image(filename='input/Out-In.png')

# %% [markdown]
# Para confirmar estos datos se realiza una matriz de correlación entre las distintas variables,y su correspondiente heatmap,observandose que existe una gran correlación entre el número de muertos y los que mueren en estancias cerradas,ya que los contaminantes tienen efectos mucho más nocivos para la salud.

# %%
Image(filename='input/Heatmap.png')

# %% [markdown]
# Una vez confirmado el efecto de los contaminantes según la estancia en la que se encuentren,se analiza el número total de muertos que producen en el exterior debido a contaminantes antropogénicos y a los producidos por el ozono,observandose un mayor número de muertos en el caso de los contaminantes que provienen de actividades antropogénicas,causadas por el ser humano.

# %%
Image(filename='input/Ozone.png')

# %% [markdown]
# ## Conclusión

# %% [markdown]
# Una vez analizados los distintos datos se puede concluir la importancia de las medidas preventivas que recogen los protocolos de contaminación,ya que se ha observado que aquellos paises con menos recursos económicos para aplicarlas tienen un mayor indice de muertos,aunque estos se han visto reducidos respecto decadas anteriores,en los que seguramente no aplicaban ninguna medida preventiva.
# También se ha podido observar que los contaminantes debidos a actividades antropogénicas,es decir,al ser humano producen un mayor número de muertos.
# Por lo tanto esto corrobora que tanto las medidas preventivas como las restricciones marcadas en los protocolos anticontaminación,como podría ser el de Kioto,son fundamentales.

# %%
Image(filename='input/Consecuencias.png')
